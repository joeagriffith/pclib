# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
dir = 'examples/mnist/out/logs/fc/unsup_iPC/size/784-64/encoder/reduction.csv'

df = pd.read_csv(dir)

df.head(10)
# Out:
#   Unnamed: 0             VFE/val           VFE/train           Corr/train  \
# 0        NaN                mean                mean                 mean
# 1       step                 NaN                 NaN                  NaN
# 2          0  38.642730712890625   44.78839340209961   0.1404806911945343
# 3          1                 NaN   44.25084762573242  0.14133988320827484
# 4          2                 NaN  43.673657989501955   0.1454585909843445
# 5          3                 NaN   43.02329788208008  0.15454396605491638
# 6          4                 NaN   42.27539596557617   0.1711899846792221
# 7          5                 NaN   41.41707305908203  0.19651895463466645
# 8          6                 NaN   40.44792251586914  0.22931937575340272
# 9          7                 NaN   39.37929763793945    0.266940975189209
#
#   Sparsity/train    X_norms/layer_0   Layer_VFE/layer_0      X_norms/layer_1  \
# ...
