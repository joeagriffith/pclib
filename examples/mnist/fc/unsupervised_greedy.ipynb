# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.datasets as datasets
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
# %matplotlib inline
import os

from pclib.nn.models import FCClassifierUsGreedy
from pclib.optim.train import train
from pclib.optim.eval import track_vfe, accuracy
from pclib.utils.functional import identity
from pclib.utils.customdataset import PreloadedDataset

# %%
seed = 42
# For reproducibility
os.environ['CUBLAS_WORKSPACE_CONFIG'] = ':4096:8'
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
torch.manual_seed(seed)

train_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.RandomAffine(degrees=10, translate=(0.1, 0.1), scale=(0.9, 1.1)),                                
    # transforms.Normalize((0.1307,), (0.3081,)),
])

val_transform = transforms.Compose([
    transforms.ToTensor(),
    # transforms.Normalize((0.1307,), (0.3081,)),
])

dataset = datasets.MNIST('../Datasets/', train=True, download=False, transform=transforms.ToTensor())

VAL_RATIO = 0.2
val_len = int(len(dataset) * VAL_RATIO)
train_len = len(dataset) - val_len
train_dataset, val_dataset = torch.utils.data.random_split(dataset, [train_len, val_len])
train_dataset = PreloadedDataset.from_dataset(train_dataset, train_transform, device)
val_dataset = PreloadedDataset.from_dataset(val_dataset, val_transform, device)

INPUT_SHAPE = 784
NUM_CLASSES = 10
# Out:
#   0%|          | 0/48000 [00:00<?, ?it/s]

# %%
train_dataset.apply_transform()
# Show some images
fig, axes = plt.subplots(1, 10, figsize=(15, 5))
idxs = torch.randperm(len(train_dataset))[:10]
for i, ax in enumerate(axes):
    img, label = train_dataset[idxs[i]]
    ax.imshow(img.squeeze().cpu(), cmap='gray')
    ax.axis('off')
plt.show()

# print max min values
print('Max value: ', train_dataset.transformed_images.max())
print('Min value: ', train_dataset.transformed_images.min())
# Out:
# Max value:  tensor(1., device='cuda:0')
# Min value:  tensor(0., device='cuda:0')

# %%
torch.manual_seed(seed)

model_name = 'WB-like-normgrads'
model = FCClassifierUsGreedy(
    in_features=INPUT_SHAPE, 
    num_classes=NUM_CLASSES, 
    hidden_sizes=[600, 600],
    bias=True, 
    symmetric=True, 
    actv_fn=F.sigmoid,
    steps=20,
    gamma=0.5,
    temp_k=0.0,
    ).to(device)

# %%
# Train Loop
BATCH_SIZE = 1000

log_dir = f'examples/mnist/out/logs/unsup_greedy/{model_name}'
# log_dir=None

NUM_EPOCHS = 250
train(
    model, 
    train_dataset, 
    val_dataset, 
    NUM_EPOCHS, 
    lr=0.0001,
    c_lr=0.0,
    batch_size=BATCH_SIZE,
    reg_coeff=0.00,
    optim='AdamW',
    # optim='SGD',
    log_dir=log_dir,
    scheduler='ReduceLROnPlateau',
    learn_layer=1,
    norm_grads=True,
)
NUM_EPOCHS = 250
train(
    model, 
    train_dataset, 
    val_dataset, 
    NUM_EPOCHS, 
    lr=0.0001,
    c_lr=0.0,
    batch_size=BATCH_SIZE,
    reg_coeff=0.00,
    optim='AdamW',
    # optim='SGD',
    log_dir=log_dir,
    scheduler='ReduceLROnPlateau',
    learn_layer=2,
    norm_grads=True,
)
NUM_EPOCHS = 150
train(
    model, 
    train_dataset, 
    val_dataset, 
    NUM_EPOCHS, 
    lr=0.0,
    c_lr=0.001,
    batch_size=BATCH_SIZE,
    reg_coeff=0.02,
    optim='AdamW',
    log_dir=log_dir,
    scheduler='ReduceLROnPlateau',
)
# Out:
# Epoch [0/250]:   0%|          | 0/48 [00:00<?, ?it/s]
# Epoch 00007: reducing learning rate of group 0 to 1.0000e-05.
# Epoch 00013: reducing learning rate of group 0 to 1.0000e-06.
# Epoch 00019: reducing learning rate of group 0 to 1.0000e-07.
# Epoch 00025: reducing learning rate of group 0 to 1.0000e-08.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 8
#       5 # log_dir=None
#       7 NUM_EPOCHS = 250
# ----> 8 train(
#       9     model,
#      10     train_dataset,
#      11     val_dataset,
#      12     NUM_EPOCHS,
#      13     lr=0.0001,
#      14     c_lr=0.0,
#      15     batch_size=BATCH_SIZE,
#      16     reg_coeff=0.00,
#      17     optim='AdamW',
#      18     # optim='SGD',
#      19     log_dir=log_dir,
#      20     scheduler='ReduceLROnPlateau',
#      21     learn_layer=1,
#      22     norm_grads=True,
#      23 )
#      24 NUM_EPOCHS = 250
#      25 train(
#      26     model,
#      27     train_dataset,
#    (...)
#      39     norm_grads=True,
#      40 )
#
# File c:\Users\joeag\Documents\pclib\pclib\optim\train.py:309, in train(model, train_data, val_data, num_epochs, lr, c_lr, batch_size, reg_coeff, flatten, neg_coeff, untr_coeff, log_dir, model_dir, minimal_stats, assert_grads, optim, scheduler, no_momentum, norm_grads, norm_weights, learn_layer, sparse_coeff)
#     304 for epoch in range(num_epochs):
#     305
#     306     # This applies the same transform to dataset in batches.
#     307     # Items in same batch with have same augmentation, but process is much faster.
#     308     if hasattr(train_data, 'apply_transform'):
# --> 309         train_data.apply_transform(batch_size=batch_size)
#     311     # A second set of statistics for each epoch
#     312     # Later aggregated into stats
#     313     epoch_stats = init_stats(model, minimal_stats, c_optimiser is not None)
#
# File c:\Users\joeag\Documents\pclib\pclib\utils\customdataset.py:102, in PreloadedDataset.apply_transform(self, device, batch_size)
#     100 if high > len(self.images):
#     101     high = len(self.images)
# --> 102 self.transformed_images[low:high] = self.transform(self.images[low:high].to(device)).to(self.device)
#     103 low += batch_size
#     104 high += batch_size
#
# File c:\Users\joeag\Documents\venvs\ml-env\Lib\site-packages\torchvision\transforms\transforms.py:95, in Compose.__call__(self, img)
#      93 def __call__(self, img):
#      94     for t in self.transforms:
# ---> 95         img = t(img)
#      96     return img
#
# File c:\Users\joeag\Documents\venvs\ml-env\Lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\joeag\Documents\venvs\ml-env\Lib\site-packages\torchvision\transforms\transforms.py:1536, in RandomAffine.forward(self, img)
#    1532 img_size = [width, height]  # flip for keeping BC on get_params call
#    1534 ret = self.get_params(self.degrees, self.translate, self.scale, self.shear, img_size)
# -> 1536 return F.affine(img, *ret, interpolation=self.interpolation, fill=fill, center=self.center)
#
# File c:\Users\joeag\Documents\venvs\ml-env\Lib\site-packages\torchvision\transforms\functional.py:1246, in affine(img, angle, translate, scale, shear, interpolation, fill, center)
#    1244 translate_f = [1.0 * t for t in translate]
#    1245 matrix = _get_inverse_affine_matrix(center_f, angle, translate_f, scale, shear)
# -> 1246 return F_t.affine(img, matrix=matrix, interpolation=interpolation.value, fill=fill)
#
# File c:\Users\joeag\Documents\venvs\ml-env\Lib\site-packages\torchvision\transforms\_functional_tensor.py:617, in affine(img, matrix, interpolation, fill)
#     615 shape = img.shape
#     616 # grid will be generated on the same device as theta and img
# --> 617 grid = _gen_affine_grid(theta, w=shape[-1], h=shape[-2], ow=shape[-1], oh=shape[-2])
#     618 return _apply_grid_transform(img, grid, interpolation, fill=fill)
#
# File c:\Users\joeag\Documents\venvs\ml-env\Lib\site-packages\torchvision\transforms\_functional_tensor.py:593, in _gen_affine_grid(theta, w, h, ow, oh)
#     579 def _gen_affine_grid(
#     580     theta: Tensor,
#     581     w: int,
#    (...)
#     589     # 1) we normalize grid values after applying theta
#     590     # 2) we can normalize by other image size, such that it covers "extend" option like in PIL.Image.rotate
#     592     d = 0.5
# --> 593     base_grid = torch.empty(1, oh, ow, 3, dtype=theta.dtype, device=theta.device)
#     594     x_grid = torch.linspace(-ow * 0.5 + d, ow * 0.5 + d - 1, steps=ow, device=theta.device)
#     595     base_grid[..., 0].copy_(x_grid)
#
# KeyboardInterrupt:

# %%
X = train_dataset.transformed_images
X_noisy = X + torch.randn_like(X) * 2.0
X_noisy = F.normalize(X_noisy, dim=1) * X.norm(dim=1, keepdim=True)
X_noisy_recon = model.reconstruct(X_noisy.to(device).flatten(1))[0].view(-1, 1, 28, 28).cpu()
X_partial = X * (torch.rand_like(X) < 0.5).float()
X_partial_recon = model.reconstruct(X_partial.to(device).flatten(1))[0].view(-1, 1, 28, 28).cpu()

# Show all 10 images, raw, noised and reconstructed
fig, axes = plt.subplots(5, 10, figsize=(15, 5))
for i, ax in enumerate(axes[0]):
    ax.imshow(X[i].squeeze().cpu(), cmap='gray')
    ax.axis('off')
for i, ax in enumerate(axes[1]):
    ax.imshow(X_noisy[i].squeeze().cpu(), cmap='gray')
    ax.axis('off')
for i, ax in enumerate(axes[2]):
    ax.imshow(X_noisy_recon[i].squeeze().cpu(), cmap='gray')
    ax.axis('off')
for i, ax in enumerate(axes[3]):
    ax.imshow(X_partial[i].squeeze().cpu(), cmap='gray')
    ax.axis('off')
for i, ax in enumerate(axes[4]):
    ax.imshow(X_partial_recon[i].squeeze().cpu(), cmap='gray')
    ax.axis('off')

# %%
# get 10 images
images = []
noisy_images = []
partial_images = []
labels = []
for i in range(10):
    img, _ = train_dataset[i]
    images.append(img)
    noisy_images.append(img + torch.randn_like(img) * 0.1)
    partial_images.append(img * (torch.rand_like(img) < 0.5))
    labels.append(label)

# show images
fig, axes = plt.subplots(3, 10, figsize=(15, 5))
for i, ax in enumerate(axes[0]):
    ax.imshow(images[i].squeeze().cpu(), cmap='gray')
    ax.axis('off')
for i, ax in enumerate(axes[1]):
    ax.imshow(noisy_images[i].squeeze().cpu(), cmap='gray')
    ax.axis('off')
for i, ax in enumerate(axes[2]):
    ax.imshow(partial_images[i].squeeze().cpu(), cmap='gray')
    ax.axis('off')
plt.show()

images = torch.stack(images).flatten(1)
noisy_images = torch.stack(noisy_images).flatten(1)
partial_images = torch.stack(partial_images).flatten(1)

# %%
# reconstruct noisy images
out, state = model.reconstruct(noisy_images)
print(out.shape)


# show reconstructed images
fig, axes = plt.subplots(1, 10, figsize=(15, 5))
for i, ax in enumerate(axes):
    ax.imshow(out[i].cpu().reshape(28, 28), cmap='gray')
    ax.axis('off')
# Out:
# torch.Size([10, 784])

# %%
# reconstruct partial images
out, state = model.reconstruct(partial_images)

# show reconstructed images
fig, axes = plt.subplots(1, 10, figsize=(15, 5))
for i, ax in enumerate(axes):
    ax.imshow(out[i].cpu().reshape(28, 28), cmap='gray')
    ax.axis('off')

# %%
# Current Accuracy and Error Rate
acc = accuracy(model, val_dataset, steps=0)
error = 100 * (1 - acc)
print(f'Current Val Acc: {acc} | error_rate: {error:0.2f} %')
# Out:
# Current Val Acc: 0.25275 | error_rate: 74.72 %

# %%
from pclib.utils.functional import format_y
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=512, shuffle=True)
images, y = next(iter(train_loader))
x = images.view(images.shape[0], -1)
y = format_y(y, 10)
vfes, X, E = track_vfe(model, x=x, steps=100, plot_Es=True, plot_Xs=True)
for i in range(len(model.layers)):
    print(f'Layer {i} e_min, e_max, x_min, x_max: {min(E[i]):.3f}, {max(E[i]):.3f}, {min(X[i]):.3f}, {max(X[i]):.3f}')
# Out:
# Layer 0 e_min, e_max, x_min, x_max: 789.656, 789.656, 1274.530, 2125.760
# Layer 1 e_min, e_max, x_min, x_max: 612.253, 4173.938, 677.809, 947.602
# Layer 2 e_min, e_max, x_min, x_max: 643.286, 15684.948, 945.730, 1438.842
# Layer 3 e_min, e_max, x_min, x_max: 693.373, 20739.857, 0.000, 0.000
