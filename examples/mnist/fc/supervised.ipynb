# %%
import torch
import torch.nn.functional as F
import torchvision.datasets as datasets
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
# %matplotlib inline
import os

from pclib.nn.models import FCPCN
from pclib.optim.train import train
from pclib.optim.eval import track_vfe, accuracy
from pclib.utils.functional import identity
from pclib.utils.customdataset import PreloadedDataset

# %%
seed = 42
# For reproducibility
os.environ['CUBLAS_WORKSPACE_CONFIG'] = ':4096:8'
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
torch.manual_seed(seed)
train_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.RandomAffine(degrees=10, translate=(0.1, 0.1), scale=(0.9, 1.1)),                                
    # transforms.Normalize((0.1307,), (0.3081,)),
])

val_transform = transforms.Compose([
    transforms.ToTensor(),
    # transforms.Normalize((0.1307,), (0.3081,)),
])

dataset = datasets.MNIST('../Datasets/', train=True, download=False, transform=transforms.ToTensor())

VAL_RATIO = 0.2
val_len = int(len(dataset) * VAL_RATIO)
train_len = len(dataset) - val_len
train_dataset, val_dataset = torch.utils.data.random_split(dataset, [train_len, val_len])
train_dataset = PreloadedDataset.from_dataset(train_dataset, train_transform, device)
val_dataset = PreloadedDataset.from_dataset(val_dataset, val_transform, device)
INPUT_SHAPE = 784
NUM_CLASSES = 10

# %%
# Show some images
fig, axes = plt.subplots(1, 10, figsize=(15, 5))
for i, ax in enumerate(axes):
    img, label = train_dataset[i]
    ax.imshow(img.squeeze().cpu(), cmap='gray')
    ax.axis('off')
plt.show()

# print max min values
print('Max value: ', train_dataset.transformed_images.max())
print('Min value: ', train_dataset.transformed_images.min())
# Out:
# Max value:  tensor(1., device='cuda:0')
# Min value:  tensor(0., device='cuda:0')

# %%
torch.manual_seed(seed)

model_name = 'fc_classifier'
model = FCPCN(
    sizes=[784, 600, 600, 10],
    bias=True, 
    symmetric=True, 
    actv_fn=F.relu,
    steps=20,
    gamma=0.2,
    ).to(device)

# %%
# Train Loop
NUM_EPOCHS = 60
BATCH_SIZE = 20

log_dir = f'examples/mnist/out/logs/{model_name}'
log_dir = None

train(
    model, 
    None,
    True,
    train_dataset, 
    val_dataset, 
    NUM_EPOCHS, 
    lr=0.0001,
    batch_size=BATCH_SIZE,
    reg_coeff=0.02,
    optim='AdamW',
    log_dir=log_dir,
    scheduler='ReduceLROnPlateau',
)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 8
#       5 log_dir = f'examples/mnist/out/logs/{model_name}'
#       6 log_dir = None
# ----> 8 train(
#       9     model,
#      10     None,
#      11     True,
#      12     train_dataset,
#      13     val_dataset,
#      14     NUM_EPOCHS,
#      15     lr=0.0001,
#      16     batch_size=BATCH_SIZE,
#      17     reg_coeff=0.02,
#      18     optim='AdamW',
#      19     log_dir=log_dir,
#      20     scheduler='ReduceLROnPlateau',
#      21 )
#
# File c:\Users\joeag\Documents\pclib\pclib\optim\train.py:349, in train(model, classifier, supervised, train_data, val_data, num_epochs, lr, c_lr, batch_size, reg_coeff, flatten, neg_coeff, untr_coeff, log_dir, model_dir, minimal_stats, assert_grads, optim, scheduler, no_momentum, norm_grads, norm_weights, learn_layer, sparse_coeff)
#     347 # Forward pass and gradient calculation
#     348 if supervised:
# --> 349     out, state = model(obs, y=y, pin_obs=True, pin_target=True)
#     350 else:
#     351     out, state = model(obs, pin_obs=True)
#
# File c:\Users\joeag\Documents\venvs\ml-env\Lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\joeag\Documents\pclib\pclib\nn\models\FCPCN.py:424, in FCPCN.forward(self, obs, y, pin_obs, pin_target, steps, learn_layer)
#     422 temp = self.calc_temp(i, steps)
#     423 self.step(state, gamma, pin_obs, pin_target, temp, learn_layer)
# --> 424 vfe = self.vfe(state, batch_reduction=None, learn_layer=learn_layer).detach()
#     425 if prev_vfe is not None:
#     426     mult = torch.ones_like(gamma)
#
# File c:\Users\joeag\Documents\pclib\pclib\nn\models\FCPCN.py:151, in FCPCN.vfe(self, state, batch_reduction, unit_reduction, learn_layer)
#     140     """
#     141     | Increments the number of epochs trained by n.
#     142     | Used by the trainer to keep track of the number of epochs trained.
#    (...)
#     147             Number of epochs to increment by.
#     148     """
#     149     self.epochs_trained += n
# --> 151 def vfe(self, state:List[dict], batch_reduction:str = 'mean', unit_reduction:str = 'sum', learn_layer:int = None):
#     152     """
#     153     | Calculates the Variational Free Energy (VFE) of the model.
#     154     | This is the sum of the squared prediction errors of each layer.
#    (...)
#     171             VFE of the model (scalar)
#     172     """
#     173     # Reduce units for each layer
#
# KeyboardInterrupt:

# %%
targets = torch.arange(NUM_CLASSES).to(device)
images = model.generate(targets)

fig, axes = plt.subplots(1, 10, figsize=(15, 5))
for i, ax in enumerate(axes):
    img = images[i]
    ax.imshow(img.detach().squeeze().cpu().view(28,28), cmap='gray')
    ax.axis('off')

# %%
# Current Accuracy and Error Rate
acc = accuracy(model, val_dataset, steps=0)
error = 100 * (1 - acc)
print(f'Current Val Acc: {acc} | error_rate: {error:0.2f} %')
# Out:
# Current Val Acc: 0.099 | error_rate: 90.10 %

# %%
from pclib.utils.functional import format_y
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=512, shuffle=True)
images, y = next(iter(train_loader))
x = images.view(images.shape[0], -1)
y = format_y(y, 10)
vfes, X, E = track_vfe(model, x, steps=100, plot_Es=True)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
