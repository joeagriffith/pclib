# %%
import torch
import torch.nn.functional as F
import torchvision.datasets as datasets
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
# %matplotlib inline

from pclib.nn.models import FCClassifierInvSym
from pclib.nn.layers import FCPW
from pclib.optim.train import train
from pclib.utils.plot import plot_stats
from pclib.optim.eval import track_vfe_sym, accuracy
from pclib.utils.functional import format_y
from pclib.utils.customdataset import PreloadedDataset

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
class TanhTransform(object):
    def __init__(self, a=1., b=0., c=1.0):
        self.a = a
        self.b = b
        self.c = c

    def __call__(self, img):
        return ((img * self.a).tanh() + self.b) * self.c

class InvTanhTransform(object):
    def __call__(self, img):
        num = 1 + img
        div = (1 - img).clamp(min=1e-6)
        m = 0.5 * torch.log(num / div)
        return m

class SigmoidTransform(object):
    def __call__(self, img):
        return img.sigmoid()
    
class ReLUTanhTransform(object):
    def __call__(self, img):
        return F.relu(img.tanh())

train_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.RandomAffine(degrees=10, translate=(0.1, 0.1), scale=(0.9, 1.1)),                                
    transforms.Normalize((0.1307,), (0.3081,)),
])

val_transform = transforms.Compose([
    transforms.ToTensor(),
    # InvTanhTransform(),
    transforms.Normalize((0.1307,), (0.3081,)),
    # SigmoidTransform(),
    # TanhTransform(a=2.0),
    # TanhTransform(a=1.0, b=1.0, c=0.5),
])

dataset = datasets.MNIST('../Datasets/', train=True, download=False, transform=transforms.ToTensor())
# # shorten dataset
# length = 1000
# dataset = torch.utils.data.Subset(dataset, range(length))

VAL_RATIO = 0.2
val_len = int(len(dataset) * VAL_RATIO)
train_len = len(dataset) - val_len
train_dataset, val_dataset = torch.utils.data.random_split(dataset, [train_len, val_len])
train_dataset = PreloadedDataset.from_dataset(train_dataset, train_transform, device)
val_dataset = PreloadedDataset.from_dataset(val_dataset, val_transform, device)
INPUT_SHAPE = 784
NUM_CLASSES = 10

# %%
# Show some images
fig, axes = plt.subplots(1, 10, figsize=(15, 5))
for i, ax in enumerate(axes):
    img, label = train_dataset[i]
    ax.imshow(img.squeeze().cpu(), cmap='gray')
    ax.axis('off')
plt.show()

# print max min values
print('Max value: ', train_dataset.transformed_images.max())
print('Min value: ', train_dataset.transformed_images.min())
# Out:
# Max value:  tensor(2.8215, device='cuda:0')
# Min value:  tensor(-0.4242, device='cuda:0')

# %%
seed = 42
torch.manual_seed(seed)

model = FCClassifierInvSym(
    in_features=INPUT_SHAPE, 
    num_classes=NUM_CLASSES, 
    hidden_sizes=[600, 600],
    bias=True, 
    symmetric=True, 
    precision_weighted=False,
    actv_fn=F.tanh,
    steps=100,
    gamma=0.1,
    ).to(device)
step = 0
stats = None

# %%
# Train Loop
LEARNING_RATE = 0.001
NUM_EPOCHS = 2
BATCH_SIZE = 1000
REG_COEFF = 0.05

step, stats = train(
    model, 
    train_dataset, 
    val_dataset, 
    NUM_EPOCHS, 
    LEARNING_RATE, 
    batch_size=BATCH_SIZE,
    reg_coeff=REG_COEFF,
    neg_coeff=None,
    step=step, 
    stats=stats,
    minimal_stats=True, # Full stats are not supported yet for sym layers
    optim='AdamW',
)
# LEARNING_RATE = 0.0001
# NUM_EPOCHS = 0
# step, stats = train(
#     model, 
#     train_dataset, 
#     val_dataset, 
#     NUM_EPOCHS, 
#     LEARNING_RATE, 
#     batch_size=BATCH_SIZE,
#     reg_coeff=REG_COEFF,
#     step=step, 
#     stats=stats,
#     device=device,
#     optim='AdamW',
# )

plt.subplot(1, 2, 1)
plt.plot(stats['train_vfe'], label='Train VFE')
plt.plot(stats['val_vfe'], label='Val VFE')
plt.subplot(1, 2, 2)
plt.plot(stats['val_acc'], label='Val Acc')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\joeag\Documents\pclib\examples\mnist\mnist_fc_inv_sym.ipynb Cell 6 line 7
#       <a href='vscode-notebook-cell:/c%3A/Users/joeag/Documents/pclib/examples/mnist/mnist_fc_inv_sym.ipynb#W5sZmlsZQ%3D%3D?line=3'>4</a> BATCH_SIZE = 1000
#       <a href='vscode-notebook-cell:/c%3A/Users/joeag/Documents/pclib/examples/mnist/mnist_fc_inv_sym.ipynb#W5sZmlsZQ%3D%3D?line=4'>5</a> REG_COEFF = 0.05
# ----> <a href='vscode-notebook-cell:/c%3A/Users/joeag/Documents/pclib/examples/mnist/mnist_fc_inv_sym.ipynb#W5sZmlsZQ%3D%3D?line=6'>7</a> step, stats = train(
#       <a href='vscode-notebook-cell:/c%3A/Users/joeag/Documents/pclib/examples/mnist/mnist_fc_inv_sym.ipynb#W5sZmlsZQ%3D%3D?line=7'>8</a>     model,
#       <a href='vscode-notebook-cell:/c%3A/Users/joeag/Documents/pclib/examples/mnist/mnist_fc_inv_sym.ipynb#W5sZmlsZQ%3D%3D?line=8'>9</a>     train_dataset,
#      <a href='vscode-notebook-cell:/c%3A/Users/joeag/Documents/pclib/examples/mnist/mnist_fc_inv_sym.ipynb#W5sZmlsZQ%3D%3D?line=9'>10</a>     val_dataset,
#      <a href='vscode-notebook-cell:/c%3A/Users/joeag/Documents/pclib/examples/mnist/mnist_fc_inv_sym.ipynb#W5sZmlsZQ%3D%3D?line=10'>11</a>     NUM_EPOCHS,
#      <a href='vscode-notebook-cell:/c%3A/Users/joeag/Documents/pclib/examples/mnist/mnist_fc_inv_sym.ipynb#W5sZmlsZQ%3D%3D?line=11'>12</a>     LEARNING_RATE,
#      <a href='vscode-notebook-cell:/c%3A/Users/joeag/Documents/pclib/examples/mnist/mnist_fc_inv_sym.ipynb#W5sZmlsZQ%3D%3D?line=12'>13</a>     batch_size=BATCH_SIZE,
#      <a href='vscode-notebook-cell:/c%3A/Users/joeag/Documents/pclib/examples/mnist/mnist_fc_inv_sym.ipynb#W5sZmlsZQ%3D%3D?line=13'>14</a>     reg_coeff=REG_COEFF,
#      <a href='vscode-notebook-cell:/c%3A/Users/joeag/Documents/pclib/examples/mnist/mnist_fc_inv_sym.ipynb#W5sZmlsZQ%3D%3D?line=14'>15</a>     neg_coeff=None,
#      <a href='vscode-notebook-cell:/c%3A/Users/joeag/Documents/pclib/examples/mnist/mnist_fc_inv_sym.ipynb#W5sZmlsZQ%3D%3D?line=15'>16</a>     step=step,
#      <a href='vscode-notebook-cell:/c%3A/Users/joeag/Documents/pclib/examples/mnist/mnist_fc_inv_sym.ipynb#W5sZmlsZQ%3D%3D?line=16'>17</a>     stats=stats,
#      <a href='vscode-notebook-cell:/c%3A/Users/joeag/Documents/pclib/examples/mnist/mnist_fc_inv_sym.ipynb#W5sZmlsZQ%3D%3D?line=17'>18</a>     minimal_stats=True, # Full stats are not supported yet for sym layers
#      <a href='vscode-notebook-cell:/c%3A/Users/joeag/Documents/pclib/examples/mnist/mnist_fc_inv_sym.ipynb#W5sZmlsZQ%3D%3D?line=18'>19</a>     optim='AdamW',
#      <a href='vscode-notebook-cell:/c%3A/Users/joeag/Documents/pclib/examples/mnist/mnist_fc_inv_sym.ipynb#W5sZmlsZQ%3D%3D?line=19'>20</a> )
#      <a href='vscode-notebook-cell:/c%3A/Users/joeag/Documents/pclib/examples/mnist/mnist_fc_inv_sym.ipynb#W5sZmlsZQ%3D%3D?line=20'>21</a> # LEARNING_RATE = 0.0001
#      <a href='vscode-notebook-cell:/c%3A/Users/joeag/Documents/pclib/examples/mnist/mnist_fc_inv_sym.ipynb#W5sZmlsZQ%3D%3D?line=21'>22</a> # NUM_EPOCHS = 0
#      <a href='vscode-notebook-cell:/c%3A/Users/joeag/Documents/pclib/examples/mnist/mnist_fc_inv_sym.ipynb#W5sZmlsZQ%3D%3D?line=22'>23</a> # step, stats = train(
#    (...)
#      <a href='vscode-notebook-cell:/c%3A/Users/joeag/Documents/pclib/examples/mnist/mnist_fc_inv_sym.ipynb#W5sZmlsZQ%3D%3D?line=33'>34</a> #     optim='AdamW',
#      <a href='vscode-notebook-cell:/c%3A/Users/joeag/Documents/pclib/examples/mnist/mnist_fc_inv_sym.ipynb#W5sZmlsZQ%3D%3D?line=34'>35</a> # )
#      <a href='vscode-notebook-cell:/c%3A/Users/joeag/Documents/pclib/examples/mnist/mnist_fc_inv_sym.ipynb#W5sZmlsZQ%3D%3D?line=36'>37</a> plt.subplot(1, 2, 1)
#
# File c:\Users\joeag\Documents\pclib\pclib\optim\train.py:235, in train(model, train_data, val_data, num_epochs, lr, c_lr, batch_size, reg_coeff, flatten, neg_coeff, step, stats, minimal_stats, assert_grads, grad_mode, optim)
#     232 else:
#     233     # Forward pass and gradient calculation
#     234     try:
# --> 235         out, state = model(x, y=y)
#     236     # catch typeerror if model is not supervised
#     237     except TypeError:
#
# File c:\Users\joeag\Documents\venvs\ml-env\Lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\joeag\Documents\pclib\pclib\nn\models\fc_classifier.py:247, in FCClassifier.forward(self, obs, y, steps)
#     245 for i in range(steps):
#     246     temp = self.calc_temp(i, steps)
# --> 247     self.step(state, obs, y, temp)
#     249 out = self.get_output(state)
#     251 return out, state
#
# File c:\Users\joeag\Documents\pclib\pclib\nn\models\fc_classifier.py:752, in FCClassifierInvSym.step(self, state, obs, y, temp)
#     750     bu_pred = self.layers[i-1].predict_up(state[i-1]) if i > 0 else None
#     751     td_pred = self.layers[i+1].predict_down(state[i+1]) if i < len(self.layers) - 1 else None
# --> 752     layer.update_e(state[i], bu_pred, td_pred, temp=temp)
#     754 # Update Xs
#     755 with torch.no_grad():
#
# KeyboardInterrupt:

# %%
targets = torch.arange(NUM_CLASSES).to(device)
y = format_y(targets, NUM_CLASSES)
_, state = model(y=y)
images = state[-1]['x']

fig, axes = plt.subplots(1, 10, figsize=(15, 5))
for i, ax in enumerate(axes):
    img = images[i]
    ax.imshow(img.detach().squeeze().cpu().view(28,28), cmap='gray')
    ax.axis('off')

# %%
# Current Accuracy and Error Rate
acc = accuracy(model, val_dataset, steps=0)
error = 100 * (1 - acc)
print(f'Current Val Acc: {acc} | error_rate: {error:0.2f} %')
# Out:
# Current Val Acc: 0.09983333333333333 | error_rate: 90.02 %

# %%
# # Shows statistics over multiple models. models = [model1, model2, ...]


# train_vfes = torch.tensor([stats[i]['train_vfe'][-1] for i in range(num_models)])
# val_vfes = torch.tensor([stats[i]['val_vfe'][-1] for i in range(num_models)])
# val_accs = torch.tensor([stats[i]['val_acc'][-1] for i in range(num_models)])

# # Show statistics across models, std is nan if num_models = 1
# print(f"Tra VFE - mean: {train_vfes.mean():.3f} | std: {train_vfes.std():.3f} | min: {train_vfes.min():.3f} | max: {train_vfes.max():.3f}")
# print(f"Val VFE - mean: {val_vfes.mean():.3f} | std: {val_vfes.std():.3f} | min: {val_vfes.min():.3f} | max: {val_vfes.max():.3f}")
# print(f"Val Acc - mean: {val_accs.mean():.3f} | std: {val_accs.std():.3f} | min: {val_accs.min():.3f} | max: {val_accs.max():.3f}")

# %%
from pclib.utils.functional import format_y
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=512, shuffle=True)
images, y = next(iter(train_loader))
x = images.view(images.shape[0], -1)
y = format_y(y, 10)
track_vfe_sym(model, x, y, 100, plot_Es=True)

# %%
assert isinstance(model.layers[0], PrecisionWeighted), "This cell only works for PrecisionWeighted layers"
# show diag of weight_var matrix as 28x28 image for layer 0
model = model
layer = 0
weight_var = model.layers[0].weight_var.detach().cpu().numpy()
# weight_var = model.layers[-1].weight_var.diag().reshape(28,28).detach().cpu().numpy()
plt.imshow(weight_var, cmap='gray')
plt.colorbar()
plt.show()
weight_var.min(), weight_var.max()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\joeag\Documents\pclib\examples\mnist\mnist_fc_inv_sym.ipynb Cell 11 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/joeag/Documents/pclib/examples/mnist/mnist_fc_inv_sym.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> assert isinstance(model.layers[0], PrecisionWeighted), "This cell only works for PrecisionWeighted layers"
#       <a href='vscode-notebook-cell:/c%3A/Users/joeag/Documents/pclib/examples/mnist/mnist_fc_inv_sym.ipynb#X16sZmlsZQ%3D%3D?line=1'>2</a> # show diag of weight_var matrix as 28x28 image for layer 0
#       <a href='vscode-notebook-cell:/c%3A/Users/joeag/Documents/pclib/examples/mnist/mnist_fc_inv_sym.ipynb#X16sZmlsZQ%3D%3D?line=2'>3</a> model = model
#
# NameError: name 'PrecisionWeighted' is not defined
