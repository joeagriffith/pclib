# %%
import torch
import torch.nn.functional as F
import torchvision.datasets as datasets
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
# %matplotlib inline

from pclib.nn.models import ConvClassifierInv, ConvClassifier
from pclib.nn.layers import Conv2d
from pclib.optim.train import train
from pclib.optim.eval import track_vfe, accuracy
from pclib.utils.functional import format_y
from pclib.utils.customdataset import PreloadedDataset

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
class TanhTransform(object):
    def __init__(self, a=1., b=0., c=1.0):
        self.a = a
        self.b = b
        self.c = c

    def __call__(self, img):
        return ((img * self.a).tanh() + self.b) * self.c

class InvTanhTransform(object):
    def __call__(self, img):
        num = 1 + img
        div = (1 - img).clamp(min=1e-6)
        m = 0.5 * torch.log(num / div)
        return m

class SigmoidTransform(object):
    def __call__(self, img):
        return img.sigmoid()
    
class ReLUTanhTransform(object):
    def __call__(self, img):
        return F.relu(img.tanh())

train_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.RandomAffine(degrees=10, translate=(0.1, 0.1), scale=(0.9, 1.1)),                                
    transforms.Normalize((0.1307,), (0.3081,)),
])

val_transform = transforms.Compose([
    transforms.ToTensor(),
    # InvTanhTransform(),
    transforms.Normalize((0.1307,), (0.3081,)),
    # SigmoidTransform(),
    # TanhTransform(a=2.0),
    # TanhTransform(a=1.0, b=1.0, c=0.5),
])

dataset = datasets.MNIST('../Datasets/', train=True, download=False, transform=transforms.ToTensor())
# # shorten dataset
# length = 1000
# dataset = torch.utils.data.Subset(dataset, range(length))

VAL_RATIO = 0.2
val_len = int(len(dataset) * VAL_RATIO)
train_len = len(dataset) - val_len
train_dataset, val_dataset = torch.utils.data.random_split(dataset, [train_len, val_len])
train_dataset = PreloadedDataset.from_dataset(train_dataset, train_transform, device)
val_dataset = PreloadedDataset.from_dataset(val_dataset, val_transform, device)
INPUT_SHAPE = 784
NUM_CLASSES = 10

# %%
# Show some images
fig, axes = plt.subplots(1, 10, figsize=(15, 5))
for i, ax in enumerate(axes):
    img, label = train_dataset[i]
    ax.imshow(img.squeeze().cpu(), cmap='gray')
    ax.axis('off')
plt.show()

# print max min values
print('Max value: ', train_dataset.transformed_images.max())
print('Min value: ', train_dataset.transformed_images.min())
# Out:
# Max value:  tensor(2.8215, device='cuda:0')
# Min value:  tensor(-0.4242, device='cuda:0')

# %%
seed = 42
torch.manual_seed(seed)

model = ConvClassifier(
    bias=True, 
    symmetric=True, 
    precision_weighted=False,
    actv_fn=F.relu,
    steps=60,
    gamma=0.1,
    ).to(device)
step = 0
stats = None

# %%
# Train Loop
LEARNING_RATE = 0.0001
NUM_EPOCHS = 1
BATCH_SIZE = 1000
REG_COEFF = 0.05

step, stats = train(
    model, 
    train_dataset, 
    val_dataset, 
    NUM_EPOCHS, 
    LEARNING_RATE, 
    batch_size=BATCH_SIZE,
    reg_coeff=REG_COEFF,
    step=step, 
    flatten=False,
    stats=stats,
    device=device,
    optim='AdamW',
)

LEARNING_RATE = 0.00001
NUM_EPOCHS = 0
step, stats = train(
    model, 
    train_dataset, 
    val_dataset, 
    NUM_EPOCHS, 
    LEARNING_RATE, 
    batch_size=BATCH_SIZE,
    reg_coeff=REG_COEFF,
    flatten=False,
    step=step, 
    stats=stats,
    device=device,
    optim='AdamW',
)

# plot_stats(stats, model) # Make Conv version
# Out:
#   0%|          | 0/48 [00:00<?, ?it/s]
# Updating_e: Layer 4 x requires grad: False
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
#   2%|▏         | 1/48 [00:01<01:05,  1.39s/it]
# Updating_e: Layer 4 x requires grad: False
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
#   4%|▍         | 2/48 [00:02<00:47,  1.04s/it]
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: False
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# ...
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: False
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# Updating x for layer 0
# Updating x for layer 1
# Updating x for layer 2
# Updating x for layer 3
# Updating x for layer 4
# Updating x for layer 5
# Updating_e: Layer 4 x requires grad: True
# Updating_e: Layer 3 x requires grad: True
# Updating_e: Layer 2 x requires grad: True
# Updating_e: Layer 1 x requires grad: True
# Updating_e: Layer 0 x requires grad: True
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 7
#       4 BATCH_SIZE = 1000
#       5 REG_COEFF = 0.05
# ----> 7 step, stats = train(
#       8     model,
#       9     train_dataset,
#      10     val_dataset,
#      11     NUM_EPOCHS,
#      12     LEARNING_RATE,
#      13     batch_size=BATCH_SIZE,
#      14     reg_coeff=REG_COEFF,
#      15     step=step,
#      16     flatten=False,
#      17     stats=stats,
#      18     device=device,
#      19     optim='AdamW',
#      20 )
#      22 LEARNING_RATE = 0.00001
#      23 NUM_EPOCHS = 0
#
# File c:\Users\joeag\Documents\pclib\pclib\optim\train_conv.py:100, in train_conv(model, train_data, val_data, num_epochs, lr, batch_size, reg_coeff, flatten, init_mode, neg_coeff, step, stats, device, optim)
#      96 step += b_size
#      98 # Forward pass
#      99 # with torch.no_grad():
# --> 100 out, state = model(x, y=y)
#     102 # Calculate grads, different equations for each implementation, top_down is f(Wr) or Wf(r)
#     103 # Grads calculated in last step
#     104 # model.zero_grad()
#    (...)
#     111
#     112 # A negative phase pass, increases VFE for negative data
#     113 if neg_coeff is not None and neg_coeff > 0:
#     114     # Forward pass
#
# File c:\Users\joeag\Documents\venvs\ml-env\Lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\joeag\Documents\pclib\pclib\nn\models\conv_classifier.py:279, in ConvClassifier.forward(self, obs, y, steps)
#     277     temp = self.calc_temp(i, steps)
#     278     # self.step(state, obs, y, temp)
# --> 279     self.step(state, temp=temp)
#     281 out = self.get_output(state)
#     283 return out, state
#
# File c:\Users\joeag\Documents\pclib\pclib\nn\models\conv_classifier.py:138, in ConvClassifier.step(self, state, obs, y, temp)
#     135         elif isinstance(layer, (Conv2d, ConvTranspose2d)) and isinstance(self.layers[i-1], FC):
#     136             pred = pred.flatten(1)
# --> 138 self.vfe(state).backward(retain_graph=True)
#     139 # for i, layer in enumerate(self.layers):
#     140 #     if isinstance(layer, (Conv2d, ConvTranspose2d)):
#     141 #         if i == 0 and obs is not None:
#    (...)
#     144 #             continue
#     145 #         state[i]['x'].grad = -2 * (torch.)
#     147 for i, layer in enumerate(self.layers):
#
# File c:\Users\joeag\Documents\venvs\ml-env\Lib\site-packages\torch\_tensor.py:487, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     477 if has_torch_function_unary(self):
#     478     return handle_torch_function(
#     479         Tensor.backward,
#     480         (self,),
#    (...)
#     485         inputs=inputs,
#     486     )
# --> 487 torch.autograd.backward(
#     488     self, gradient, retain_graph, create_graph, inputs=inputs
#     489 )
#
# File c:\Users\joeag\Documents\venvs\ml-env\Lib\site-packages\torch\autograd\__init__.py:200, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     195     retain_graph = create_graph
#     197 # The reason we repeat same the comment below is that
#     198 # some Python versions print out the first line of a multi-line function
#     199 # calls in the traceback and some print out the last line
# --> 200 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     201     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     202     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:

# %%
plt.plot(stats['val_acc'])

# %%
for p in model.parameters():
    p.requires_grad = True
    print(p.shape)
# Out:
# torch.Size([32, 1, 5, 5])
# torch.Size([1])
# torch.Size([64, 32, 5, 5])
# torch.Size([32])
# torch.Size([64, 64, 5, 5])
# torch.Size([64])
# torch.Size([576, 128])
# torch.Size([576])
# torch.Size([128, 10])
# torch.Size([128])

# %%
kernel = 3
padding = 1
stride = 1
in_features = 1
out_features = 4

conv = torch.nn.Conv2d(in_features, out_features, kernel, stride, padding)
convt = torch.nn.ConvTranspose2d(out_features, in_features, kernel, stride, padding)

x = torch.randn(1, 1, 28, 28)
y = conv(x)
x_hat = convt(y)

print(f"x.shape: {x.shape}")
print(f"y.shape: {y.shape}")
print(f"x_hat.shape: {x_hat.shape}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\joeag\Documents\pclib\examples\mnist\mnist_pcconv.ipynb Cell 7 line 7
#       <a href='vscode-notebook-cell:/c%3A/Users/joeag/Documents/pclib/examples/mnist/mnist_pcconv.ipynb#X24sZmlsZQ%3D%3D?line=3'>4</a> in_features = 1
#       <a href='vscode-notebook-cell:/c%3A/Users/joeag/Documents/pclib/examples/mnist/mnist_pcconv.ipynb#X24sZmlsZQ%3D%3D?line=4'>5</a> out_features = 4
# ----> <a href='vscode-notebook-cell:/c%3A/Users/joeag/Documents/pclib/examples/mnist/mnist_pcconv.ipynb#X24sZmlsZQ%3D%3D?line=6'>7</a> conv = torch.nn.Conv2d(in_features, out_features, kernel, stride, padding)
#       <a href='vscode-notebook-cell:/c%3A/Users/joeag/Documents/pclib/examples/mnist/mnist_pcconv.ipynb#X24sZmlsZQ%3D%3D?line=7'>8</a> convt = torch.nn.ConvTranspose2d(out_features, in_features, kernel, stride, padding)
#      <a href='vscode-notebook-cell:/c%3A/Users/joeag/Documents/pclib/examples/mnist/mnist_pcconv.ipynb#X24sZmlsZQ%3D%3D?line=9'>10</a> x = torch.randn(1, 1, 28, 28)
#
# NameError: name 'torch' is not defined

# %%
targets = torch.arange(NUM_CLASSES).to(device)
y = format_y(targets, NUM_CLASSES)
_, state = model(y=y, lmda=0.00)
images = state[-1]['x']

fig, axes = plt.subplots(1, 10, figsize=(15, 5))
for i, ax in enumerate(axes):
    img = images[i]
    ax.imshow(img.detach().squeeze().cpu().view(28,28), cmap='gray')
    ax.axis('off')

# %%
plt.plot(stats['val_acc'])
plt.title("Validation Accuracy")
plt.show()

# %%
def run():
    x = torch.randn(1000, 1, 28, 28).to(device)
    out = model(x, steps=100)

# %timeit run()
for p in model.parameters():
    p.requires_grad = False
# %timeit run()
# Out:
# 1.28 s ± 1.9 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 1.03 s ± 2.31 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# Current Accuracy and Error Rate
acc = accuracy(model, val_dataset, steps=0)
error = 100 * (1 - acc)
print(f'Current Val Acc: {acc} | error_rate: {error:0.2f} %')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[10], line 2
#       1 # Current Accuracy and Error Rate
# ----> 2 acc = accuracy(model, val_dataset, steps=0)
#       3 error = 100 * (1 - acc)
#       4 print(f'Current Val Acc: {acc} | error_rate: {error:0.2f} %')
#
# File c:\Users\joeag\Documents\pclib\pclib\optim\eval.py:76, in accuracy(model, dataset, batch_size, steps, flatten)
#      74     if flatten:
#      75         x = x.flatten(start_dim=1)
# ---> 76     pred = model.classify(x, steps)
#      77     correct += (pred == y).sum().item()
#      78 acc = correct/len(dataset)
#
# File c:\Users\joeag\Documents\pclib\pclib\nn\models\conv_classifier.py:320, in ConvClassifier.classify(self, obs, state, steps)
#     318     targets = torch.full((obs.shape[0],), target, device=self.device, dtype=torch.long)
#     319     y = format_y(targets, self.num_classes)
# --> 320     _, state = self.forward(obs, y, steps)
#     321     vfes[:, target] = self.vfe(state, batch_reduction=None)
#     323 return vfes.argmin(dim=1)
#
# File c:\Users\joeag\Documents\pclib\pclib\nn\models\conv_classifier.py:280, in ConvClassifier.forward(self, obs, y, steps)
#     278 for i in range(steps):
#     279     temp = self.calc_temp(i, steps)
# --> 280     self.step(state, obs, y, temp)
#     282 out = self.get_output(state)
#     284 return out, state
#
# File c:\Users\joeag\Documents\pclib\pclib\nn\models\conv_classifier.py:128, in ConvClassifier.step(self, state, obs, y, temp)
#     126 for i, layer in reversed(list(enumerate(self.layers))):
#     127     if i < len(self.layers) - 1: # don't update top e (no prediction)
# --> 128         layer.update_e(state[i], pred, temp=temp)
#     129     if i > 0: # Bottom layer can't predict
#     130         pred = layer.predict(state[i])
#
# File c:\Users\joeag\Documents\pclib\pclib\nn\layers\conv.py:104, in Conv2d.update_e(self, state, pred, temp)
#     102 def update_e(self, state, pred=None, temp=None):
#     103     if pred is not None:
# --> 104         state['e'] = state['x'] - pred
#     106     if temp is not None:
#     107         eps = torch.randn_like(state['e'], device=self.device) * 0.034 * temp
#
# RuntimeError: The size of tensor a (784) must match the size of tensor b (28) at non-singleton dimension 3

# %%
# # Shows statistics over multiple models. models = [model1, model2, ...]


# train_vfes = torch.tensor([stats[i]['train_vfe'][-1] for i in range(num_models)])
# val_vfes = torch.tensor([stats[i]['val_vfe'][-1] for i in range(num_models)])
# val_accs = torch.tensor([stats[i]['val_acc'][-1] for i in range(num_models)])

# # Show statistics across models, std is nan if num_models = 1
# print(f"Tra VFE - mean: {train_vfes.mean():.3f} | std: {train_vfes.std():.3f} | min: {train_vfes.min():.3f} | max: {train_vfes.max():.3f}")
# print(f"Val VFE - mean: {val_vfes.mean():.3f} | std: {val_vfes.std():.3f} | min: {val_vfes.min():.3f} | max: {val_vfes.max():.3f}")
# print(f"Val Acc - mean: {val_accs.mean():.3f} | std: {val_accs.std():.3f} | min: {val_accs.min():.3f} | max: {val_accs.max():.3f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\joeag\Documents\pclib\mnist\mnist_pclinear.ipynb Cell 7 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/joeag/Documents/pclib/mnist/mnist_pclinear.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> train_vfes = torch.tensor([stats[i]['train_vfe'][-1] for i in range(num_models)])
#       <a href='vscode-notebook-cell:/c%3A/Users/joeag/Documents/pclib/mnist/mnist_pclinear.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a> val_vfes = torch.tensor([stats[i]['val_vfe'][-1] for i in range(num_models)])
#       <a href='vscode-notebook-cell:/c%3A/Users/joeag/Documents/pclib/mnist/mnist_pclinear.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a> val_accs = torch.tensor([stats[i]['val_acc'][-1] for i in range(num_models)])
#
# NameError: name 'num_models' is not defined

# %%
from pclib.utils.functional import format_y
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=512, shuffle=True)
images, y = next(iter(train_loader))
x = images
y = format_y(y, 10)

track_vfe(model, x, y, 100, plot_Es=True)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[11], line 7
#       4 x = images
#       5 y = format_y(y, 10)
# ----> 7 track_vfe(model, x, y, 100, plot_Es=True)
#
# File c:\Users\joeag\Documents\pclib\pclib\optim\eval.py:22, in track_vfe(model, x, y, steps, plot_Es, plot_Xs)
#      20 with torch.no_grad():
#      21     temp = model.calc_temp(step_i, steps)
# ---> 22     model.step(state, x, y, temp)
#      23     vfes.append(model.vfe(state).item())
#      24     for i in range(len(model.layers)):
#
# File c:\Users\joeag\Documents\pclib\pclib\nn\models\conv_classifier.py:137, in ConvClassifier.step(self, state, obs, y, temp)
#     134         elif isinstance(layer, (Conv2d, ConvTranspose2d)) and isinstance(self.layers[i-1], FC):
#     135             pred = pred.flatten(1)
# --> 137 self.vfe(state).backward(retain_graph=True)
#     138 # for i, layer in enumerate(self.layers):
#     139 #     if isinstance(layer, (Conv2d, ConvTranspose2d)):
#     140 #         if i == 0 and obs is not None:
#    (...)
#     143 #             continue
#     144 #         state[i]['x'].grad = -2 * (torch.)
#     146 for i, layer in enumerate(self.layers):
#
# File c:\Users\joeag\Documents\venvs\ml-env\Lib\site-packages\torch\_tensor.py:487, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     477 if has_torch_function_unary(self):
#     478     return handle_torch_function(
#     479         Tensor.backward,
#     480         (self,),
#    (...)
#     485         inputs=inputs,
#     486     )
# --> 487 torch.autograd.backward(
#     488     self, gradient, retain_graph, create_graph, inputs=inputs
#     489 )
#
# File c:\Users\joeag\Documents\venvs\ml-env\Lib\site-packages\torch\autograd\__init__.py:200, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     195     retain_graph = create_graph
#     197 # The reason we repeat same the comment below is that
#     198 # some Python versions print out the first line of a multi-line function
#     199 # calls in the traceback and some print out the last line
# --> 200 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     201     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     202     allow_unreachable=True, accumulate_grad=True)
#
# RuntimeError: element 0 of tensors does not require grad and does not have a grad_fn

# %%
assert isinstance(model.layers[0], PrecisionWeighted), "This cell only works for PrecisionWeighted layers"
# show diag of weight_var matrix as 28x28 image for layer 0
model = model
layer = 0
weight_var = model.layers[0].weight_var.detach().cpu().numpy()
# weight_var = model.layers[-1].weight_var.diag().reshape(28,28).detach().cpu().numpy()
plt.imshow(weight_var, cmap='gray')
plt.colorbar()
plt.show()
weight_var.min(), weight_var.max()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# c:\Users\joeag\Documents\pclib\examples\mnist\mnist_pclinear.ipynb Cell 12 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/joeag/Documents/pclib/examples/mnist/mnist_pclinear.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> assert isinstance(model.layers[0], PrecisionWeighted), "This cell only works for PrecisionWeighted layers"
#       <a href='vscode-notebook-cell:/c%3A/Users/joeag/Documents/pclib/examples/mnist/mnist_pclinear.ipynb#X14sZmlsZQ%3D%3D?line=1'>2</a> # show diag of weight_var matrix as 28x28 image for layer 0
#       <a href='vscode-notebook-cell:/c%3A/Users/joeag/Documents/pclib/examples/mnist/mnist_pclinear.ipynb#X14sZmlsZQ%3D%3D?line=2'>3</a> model = model
#
# AssertionError: This cell only works for PrecisionWeighted layers
