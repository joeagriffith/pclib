# %%
import torch
import torch.nn.functional as F
import torchvision.datasets as datasets
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
# %matplotlib inline

from pclib.nn.models import PCLinearClassifier
from pclib.nn.layers import PrecisionWeighted
from pclib.optim.train import train
from pclib.utils.plot import plot_stats
from pclib.optim.eval import track_vfe, accuracy
from pclib.utils.functional import vfe, format_y
from pclib.utils.customdataset import PreloadedDataset
# Out:
# c:\Users\joeag\Documents\pclib\pclib\nn\layers\linear.py:127: SyntaxWarning: assertion is always true, perhaps remove parentheses?
#   assert(torch.eq(F.normalize(self.weight_td.grad, dim=(0,1)), F.normalize(true_weight_td_grad, dim=(0,1))).all(), f"true: {true_weight_td_grad}, backprop: {self.weight_td.grad}")
# c:\Users\joeag\Documents\pclib\pclib\nn\layers\linear.py:128: SyntaxWarning: assertion is always true, perhaps remove parentheses?
#   assert(torch.eq(self.weight_td.grad.norm(dim=(0,1)), true_weight_td_grad.norm(dim=(0,1))).all(), f"true: {true_weight_td_grad.norm(dim=(0,1))}, backprop: {self.weight_td.grad.norm(dim=(0,1))}")
# c:\Users\joeag\Documents\pclib\pclib\nn\layers\linear.py:129: SyntaxWarning: assertion is always true, perhaps remove parentheses?
#   assert(torch.eq(self.weight_td.grad, true_weight_td_grad).all(), f"true: {true_weight_td_grad}, backprop: {self.weight_td.grad}")
# c:\Users\joeag\Documents\pclib\pclib\nn\layers\linear.py:132: SyntaxWarning: assertion is always true, perhaps remove parentheses?
#   assert(torch.eq(F.normalize(self.bias.grad, dim=0), F.normalize(true_bias_grad, dim=0)).all(), f"true: {true_bias_grad}, backprop: {self.bias.grad}")
# c:\Users\joeag\Documents\pclib\pclib\nn\layers\linear.py:133: SyntaxWarning: assertion is always true, perhaps remove parentheses?
#   assert(torch.eq(self.bias.grad.norm(), true_bias_grad.norm()).all(), f"true: {true_bias_grad.norm()}, backprop: {self.bias.grad.norm()}")
# c:\Users\joeag\Documents\pclib\pclib\nn\layers\linear.py:134: SyntaxWarning: assertion is always true, perhaps remove parentheses?
#   assert(torch.eq(self.bias.grad, true_bias_grad).all(), f"true: {true_bias_grad}, backprop: {self.bias.grad}")
# c:\Users\joeag\Documents\pclib\pclib\nn\layers\linear.py:137: SyntaxWarning: assertion is always true, perhaps remove parentheses?
#   assert(torch.eq(F.normalize(self.weight_bu.grad, dim=(0,1)), F.normalize(true_weight_bu_grad, dim=(0,1))).all(), f"true: {true_weight_bu_grad}, backprop: {self.weight_bu.grad}")
# c:\Users\joeag\Documents\pclib\pclib\nn\layers\linear.py:138: SyntaxWarning: assertion is always true, perhaps remove parentheses?
#   assert(torch.eq(self.weight_bu.grad.norm(dim=(0,1)), true_weight_bu_grad.norm(dim=(0,1))).all(), f"true: {true_weight_bu_grad.norm(dim=(0,1))}, backprop: {self.weight_bu.grad.norm(dim=(0,1))}")

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
class TanhTransform(object):
    def __init__(self, a=1., b=0., c=1.0):
        self.a = a
        self.b = b
        self.c = c

    def __call__(self, img):
        return ((img * self.a).tanh() + self.b) * self.c

class InvTanhTransform(object):
    def __call__(self, img):
        num = 1 + img
        div = (1 - img).clamp(min=1e-6)
        m = 0.5 * torch.log(num / div)
        return m

class SigmoidTransform(object):
    def __call__(self, img):
        return img.sigmoid()
    
class ReLUTanhTransform(object):
    def __call__(self, img):
        return F.relu(img.tanh())

train_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.RandomAffine(degrees=10, translate=(0.1, 0.1), scale=(0.9, 1.1)),                                
    transforms.Normalize((0.1307,), (0.3081,)),
])

val_transform = transforms.Compose([
    transforms.ToTensor(),
    # InvTanhTransform(),
    transforms.Normalize((0.1307,), (0.3081,)),
    # SigmoidTransform(),
    # TanhTransform(a=2.0),
    # TanhTransform(a=1.0, b=1.0, c=0.5),
])

dataset = datasets.MNIST('../Datasets/', train=True, download=False, transform=transforms.ToTensor())
# # shorten dataset
# length = 1000
# dataset = torch.utils.data.Subset(dataset, range(length))

VAL_RATIO = 0.2
val_len = int(len(dataset) * VAL_RATIO)
train_len = len(dataset) - val_len
train_dataset, val_dataset = torch.utils.data.random_split(dataset, [train_len, val_len])
train_dataset = PreloadedDataset.from_dataset(train_dataset, train_transform, device)
val_dataset = PreloadedDataset.from_dataset(val_dataset, val_transform, device)
INPUT_SHAPE = 784
NUM_CLASSES = 10
# Out:
#   0%|          | 0/48000 [00:00<?, ?it/s]

# %%
# Show some images
fig, axes = plt.subplots(1, 10, figsize=(15, 5))
for i, ax in enumerate(axes):
    img, label = train_dataset[i]
    ax.imshow(img.squeeze().cpu(), cmap='gray')
    ax.axis('off')
plt.show()

# print max min values
print('Max value: ', train_dataset.transformed_images.max())
print('Min value: ', train_dataset.transformed_images.min())
# Out:
# Max value:  tensor(2.8215, device='cuda:0')
# Min value:  tensor(-0.4242, device='cuda:0')

# %%
seed = 42
torch.manual_seed(seed)

model = PCLinearClassifier(
    input_size=INPUT_SHAPE, 
    num_classes=NUM_CLASSES, 
    hidden_sizes=[600, 600],
    bias=True, 
    symmetric=True, 
    precision_weighted=False,
    actv_fn=F.tanh,
    steps=60,
    gamma=0.1,
    beta=1.0,
    ).to(device)
step = 0
stats = None

# %%
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=512, shuffle=False)

images, labels = next(iter(train_loader))

x = images.flatten(1)
y = format_y(labels, NUM_CLASSES)

out, state = model(x, y=y)

# state = model.init_state(x, y)
# model.step(state, x, y)
# model.step(state, x, y)
# model.step(state, x, y)
# model.step(state, x, y)
# model.step(state, x, y)
# model.step(state, x, y)
# model.step(state, x, y)
# for i, state_i in enumerate(state):
#     print(f"layer {i} x mean: {state_i['x'].abs().mean()}")
#     print(f"layer {i} e mean: {state_i['e'].abs().mean()}")

model.zero_grad()
vfe(state).backward()
# for i, layer in enumerate(model.layers):
#     layer.update_grad(state[i], state[i-1]['e'])

# loss = sum([state_i['e'].square().mean() for state_i in state])
# loss.backward()

for i, layer in reversed(list(enumerate(model.layers))):
    if i > 0:
        if layer.assert_grad(state[i], state[i-1]['e']):
            print(f'Layer {i} grad CORRECT, with mean: {layer.weight_td.grad.mean()}')
        else:
            print(f'Layer {i} grad INCORRECT')
# Out:
# Layer 3 grad CORRECT, with mean: -2.1630265223393508e-07
# Layer 2 grad CORRECT, with mean: 8.147948982184516e-09
# Layer 1 grad CORRECT, with mean: 9.68387394095771e-05

# %%
# Train Loop
LEARNING_RATE = 0.001
NUM_EPOCHS = 40
BATCH_SIZE = 1000
REG_COEFF = 0.05

step, stats = train(
    model, 
    train_dataset, 
    val_dataset, 
    NUM_EPOCHS, 
    LEARNING_RATE, 
    batch_size=BATCH_SIZE,
    reg_coeff=REG_COEFF,
    step=step, 
    stats=stats,
    device=device,
    optim='AdamW',
)
LEARNING_RATE = 0.0001
NUM_EPOCHS = 5
step, stats = train(
    model, 
    train_dataset, 
    val_dataset, 
    NUM_EPOCHS, 
    LEARNING_RATE, 
    batch_size=BATCH_SIZE,
    reg_coeff=REG_COEFF,
    step=step, 
    stats=stats,
    device=device,
    optim='AdamW',
)

plot_stats(stats, model)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\joeag\Documents\pclib\examples\mnist\mnist_pclinear.ipynb Cell 7 line 7
#       <a href='vscode-notebook-cell:/c%3A/Users/joeag/Documents/pclib/examples/mnist/mnist_pclinear.ipynb#W5sZmlsZQ%3D%3D?line=3'>4</a> BATCH_SIZE = 1000
#       <a href='vscode-notebook-cell:/c%3A/Users/joeag/Documents/pclib/examples/mnist/mnist_pclinear.ipynb#W5sZmlsZQ%3D%3D?line=4'>5</a> REG_COEFF = 0.05
# ----> <a href='vscode-notebook-cell:/c%3A/Users/joeag/Documents/pclib/examples/mnist/mnist_pclinear.ipynb#W5sZmlsZQ%3D%3D?line=6'>7</a> step, stats = train(
#       <a href='vscode-notebook-cell:/c%3A/Users/joeag/Documents/pclib/examples/mnist/mnist_pclinear.ipynb#W5sZmlsZQ%3D%3D?line=7'>8</a>     model,
#       <a href='vscode-notebook-cell:/c%3A/Users/joeag/Documents/pclib/examples/mnist/mnist_pclinear.ipynb#W5sZmlsZQ%3D%3D?line=8'>9</a>     train_dataset,
#      <a href='vscode-notebook-cell:/c%3A/Users/joeag/Documents/pclib/examples/mnist/mnist_pclinear.ipynb#W5sZmlsZQ%3D%3D?line=9'>10</a>     val_dataset,
#      <a href='vscode-notebook-cell:/c%3A/Users/joeag/Documents/pclib/examples/mnist/mnist_pclinear.ipynb#W5sZmlsZQ%3D%3D?line=10'>11</a>     NUM_EPOCHS,
#      <a href='vscode-notebook-cell:/c%3A/Users/joeag/Documents/pclib/examples/mnist/mnist_pclinear.ipynb#W5sZmlsZQ%3D%3D?line=11'>12</a>     LEARNING_RATE,
#      <a href='vscode-notebook-cell:/c%3A/Users/joeag/Documents/pclib/examples/mnist/mnist_pclinear.ipynb#W5sZmlsZQ%3D%3D?line=12'>13</a>     batch_size=BATCH_SIZE,
#      <a href='vscode-notebook-cell:/c%3A/Users/joeag/Documents/pclib/examples/mnist/mnist_pclinear.ipynb#W5sZmlsZQ%3D%3D?line=13'>14</a>     reg_coeff=REG_COEFF,
#      <a href='vscode-notebook-cell:/c%3A/Users/joeag/Documents/pclib/examples/mnist/mnist_pclinear.ipynb#W5sZmlsZQ%3D%3D?line=14'>15</a>     step=step,
#      <a href='vscode-notebook-cell:/c%3A/Users/joeag/Documents/pclib/examples/mnist/mnist_pclinear.ipynb#W5sZmlsZQ%3D%3D?line=15'>16</a>     stats=stats,
#      <a href='vscode-notebook-cell:/c%3A/Users/joeag/Documents/pclib/examples/mnist/mnist_pclinear.ipynb#W5sZmlsZQ%3D%3D?line=16'>17</a>     device=device,
#      <a href='vscode-notebook-cell:/c%3A/Users/joeag/Documents/pclib/examples/mnist/mnist_pclinear.ipynb#W5sZmlsZQ%3D%3D?line=17'>18</a>     optim='AdamW',
#      <a href='vscode-notebook-cell:/c%3A/Users/joeag/Documents/pclib/examples/mnist/mnist_pclinear.ipynb#W5sZmlsZQ%3D%3D?line=18'>19</a> )
#      <a href='vscode-notebook-cell:/c%3A/Users/joeag/Documents/pclib/examples/mnist/mnist_pclinear.ipynb#W5sZmlsZQ%3D%3D?line=19'>20</a> LEARNING_RATE = 0.0001
#      <a href='vscode-notebook-cell:/c%3A/Users/joeag/Documents/pclib/examples/mnist/mnist_pclinear.ipynb#W5sZmlsZQ%3D%3D?line=20'>21</a> NUM_EPOCHS = 5
#
# File c:\Users\joeag\Documents\pclib\pclib\optim\train.py:110, in train(model, train_data, val_data, num_epochs, lr, batch_size, reg_coeff, flatten, init_mode, neg_coeff, step, stats, device, optim)
#     108 for i, layer in enumerate(model.layers):
#     109     if i > 0:
# --> 110         layer.assert_grad(state[i], state[i-1]['e'])
#     112 # A negative phase pass, increases VFE for negative data
#     113 if neg_coeff is not None and neg_coeff > 0:
#     114     # Forward pass
#
# File c:\Users\joeag\Documents\pclib\pclib\nn\layers\linear.py:132, in Linear.assert_grad(self, state, e_below)
#     130 if self.bias is not None:
#     131     true_bias_grad = -e_below.mean(dim=0)
# --> 132     assert(torch.eq(F.normalize(self.bias.grad, dim=0), F.normalize(true_bias_grad, dim=0)).all(), f"true: {true_bias_grad}, backprop: {self.bias.grad}")
#     133     assert(torch.eq(self.bias.grad.norm(), true_bias_grad.norm()).all(), f"true: {true_bias_grad.norm()}, backprop: {self.bias.grad.norm()}")
#     134     assert(torch.eq(self.bias.grad, true_bias_grad).all(), f"true: {true_bias_grad}, backprop: {self.bias.grad}")
#
# File c:\Users\joeag\Documents\venvs\ml-env\Lib\site-packages\torch\_tensor.py:873, in Tensor.__format__(self, format_spec)
#     871 if self.dim() == 0 and not self.is_meta and type(self) is Tensor:
#     872     return self.item().__format__(format_spec)
# --> 873 return object.__format__(self, format_spec)
#
# File c:\Users\joeag\Documents\venvs\ml-env\Lib\site-packages\torch\_tensor.py:426, in Tensor.__repr__(self, tensor_contents)
#     422     return handle_torch_function(
#     423         Tensor.__repr__, (self,), self, tensor_contents=tensor_contents
#     424     )
#     425 # All strings are unicode in Python 3.
# --> 426 return torch._tensor_str._str(self, tensor_contents=tensor_contents)
#
# File c:\Users\joeag\Documents\venvs\ml-env\Lib\site-packages\torch\_tensor_str.py:636, in _str(self, tensor_contents)
#     634 with torch.no_grad(), torch.utils._python_dispatch._disable_current_modes():
#     635     guard = torch._C._DisableFuncTorch()
# --> 636     return _str_intern(self, tensor_contents=tensor_contents)
#
# File c:\Users\joeag\Documents\venvs\ml-env\Lib\site-packages\torch\_tensor_str.py:567, in _str_intern(inp, tensor_contents)
#     565                     tensor_str = _tensor_str(self.to_dense(), indent)
#     566                 else:
# --> 567                     tensor_str = _tensor_str(self, indent)
#     569 if self.layout != torch.strided:
#     570     suffixes.append("layout=" + str(self.layout))
#
# File c:\Users\joeag\Documents\venvs\ml-env\Lib\site-packages\torch\_tensor_str.py:327, in _tensor_str(self, indent)
#     323     return _tensor_str_with_formatter(
#     324         self, indent, summarize, real_formatter, imag_formatter
#     325     )
#     326 else:
# --> 327     formatter = _Formatter(get_summarized_data(self) if summarize else self)
#     328     return _tensor_str_with_formatter(self, indent, summarize, formatter)
#
# File c:\Users\joeag\Documents\venvs\ml-env\Lib\site-packages\torch\_tensor_str.py:160, in _Formatter.__init__(self, tensor)
#     157     self.sci_mode = True
#     158     for value in nonzero_finite_vals:
#     159         value_str = (
# --> 160             ("{{:.{}e}}").format(PRINT_OPTS.precision).format(value)
#     161         )
#     162         self.max_width = max(self.max_width, len(value_str))
#     163 else:
#
# File c:\Users\joeag\Documents\venvs\ml-env\Lib\site-packages\torch\_tensor.py:872, in Tensor.__format__(self, format_spec)
#     870     return handle_torch_function(Tensor.__format__, (self,), self, format_spec)
#     871 if self.dim() == 0 and not self.is_meta and type(self) is Tensor:
# --> 872     return self.item().__format__(format_spec)
#     873 return object.__format__(self, format_spec)
#
# KeyboardInterrupt:

# %%
targets = torch.arange(NUM_CLASSES).to(device)
y = format_y(targets, NUM_CLASSES)
_, state = model(y=y, lmda=0.00)
images = state[-1]['x']

fig, axes = plt.subplots(1, 10, figsize=(15, 5))
for i, ax in enumerate(axes):
    img = images[i]
    ax.imshow(img.detach().squeeze().cpu().view(28,28), cmap='gray')
    ax.axis('off')

# %%
plt.plot(stats['val_acc'])
plt.title("Validation Accuracy")
plt.show()

# %%
# Current Accuracy and Error Rate
acc = accuracy(model, val_dataset, steps=0)
error = 100 * (1 - acc)
print(f'Current Val Acc: {acc} | error_rate: {error:0.2f} %')
# Out:
# Current Val Acc: 0.9848333333333333 | error_rate: 1.52 %

# %%
# # Shows statistics over multiple models. models = [model1, model2, ...]


# train_vfes = torch.tensor([stats[i]['train_vfe'][-1] for i in range(num_models)])
# val_vfes = torch.tensor([stats[i]['val_vfe'][-1] for i in range(num_models)])
# val_accs = torch.tensor([stats[i]['val_acc'][-1] for i in range(num_models)])

# # Show statistics across models, std is nan if num_models = 1
# print(f"Tra VFE - mean: {train_vfes.mean():.3f} | std: {train_vfes.std():.3f} | min: {train_vfes.min():.3f} | max: {train_vfes.max():.3f}")
# print(f"Val VFE - mean: {val_vfes.mean():.3f} | std: {val_vfes.std():.3f} | min: {val_vfes.min():.3f} | max: {val_vfes.max():.3f}")
# print(f"Val Acc - mean: {val_accs.mean():.3f} | std: {val_accs.std():.3f} | min: {val_accs.min():.3f} | max: {val_accs.max():.3f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\joeag\Documents\pclib\mnist\mnist_pclinear.ipynb Cell 7 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/joeag/Documents/pclib/mnist/mnist_pclinear.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> train_vfes = torch.tensor([stats[i]['train_vfe'][-1] for i in range(num_models)])
#       <a href='vscode-notebook-cell:/c%3A/Users/joeag/Documents/pclib/mnist/mnist_pclinear.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a> val_vfes = torch.tensor([stats[i]['val_vfe'][-1] for i in range(num_models)])
#       <a href='vscode-notebook-cell:/c%3A/Users/joeag/Documents/pclib/mnist/mnist_pclinear.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a> val_accs = torch.tensor([stats[i]['val_acc'][-1] for i in range(num_models)])
#
# NameError: name 'num_models' is not defined

# %%
from pclib.utils.functional import format_y
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=512, shuffle=True)
images, y = next(iter(train_loader))
x = images.view(images.shape[0], -1)
y = format_y(y, 10)
track_vfe(model, x, y, 100, plot_Es=True)

# %%
assert isinstance(model.layers[0], PrecisionWeighted), "This cell only works for PrecisionWeighted layers"
# show diag of weight_var matrix as 28x28 image for layer 0
model = model
layer = 0
weight_var = model.layers[0].weight_var.detach().cpu().numpy()
# weight_var = model.layers[-1].weight_var.diag().reshape(28,28).detach().cpu().numpy()
plt.imshow(weight_var, cmap='gray')
plt.colorbar()
plt.show()
weight_var.min(), weight_var.max()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# c:\Users\joeag\Documents\pclib\examples\mnist\mnist_pclinear.ipynb Cell 12 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/joeag/Documents/pclib/examples/mnist/mnist_pclinear.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> assert isinstance(model.layers[0], PrecisionWeighted), "This cell only works for PrecisionWeighted layers"
#       <a href='vscode-notebook-cell:/c%3A/Users/joeag/Documents/pclib/examples/mnist/mnist_pclinear.ipynb#X14sZmlsZQ%3D%3D?line=1'>2</a> # show diag of weight_var matrix as 28x28 image for layer 0
#       <a href='vscode-notebook-cell:/c%3A/Users/joeag/Documents/pclib/examples/mnist/mnist_pclinear.ipynb#X14sZmlsZQ%3D%3D?line=2'>3</a> model = model
#
# AssertionError: This cell only works for PrecisionWeighted layers
